# %% [markdown]
# # **_Boyer-Moore_**

# %% [markdown]
# **_Boyer-Moore_** es un algoritmo de búsqueda en texto que usa una tabla de preprocesamiento para agilizar la búsqueda en texto, evitando hacer comparaciones innecesarias.
#
# Algunas diferencias de este algoritmo respecto a KMP, es que recorre el patrón **de derecha a izquierda**, y el texto **de izquierda a derecha**.  Además, usa algunas heurísticas para cuando hay _mismatches_, tales como:
#
# * _Bad character_: Es una tabla que guarda el índice de la última aparición del patrón.
# *
